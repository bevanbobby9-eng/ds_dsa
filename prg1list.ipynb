# %%
print("hello")
# Out:
# hello

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.9 MB 10.2 MB/s eta 0:00:01
#    ------------- -------------------------- 3.4/9.9 MB 9.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.8/9.9 MB 10.3 MB/s eta 0:00:01
#    ------------------------------- -------- 7.9/9.9 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 9.6 MB/s  0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data=pd.read_csv("tip.csv")

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#list operation

# %%
l1=list()

# %%
type(l1)
# Out:
# list

# %%
l1.append(10)

# %%
l1
# Out:
# [10]

# %%
l1.append(30)

# %%
l1.append(23)

# %%
l1.append(6)

# %%
l1
# Out:
# [10, 30, 23, 6]

# %%
l1[-2]
# Out:
# 23

# %%
l1.sort()

# %%
l1
# Out:
# [6, 10, 23, 30]

# %%
num=[2,4,66,5,76,23]

# %%
nums=num.sort()

# %%
num
# Out:
# [2, 4, 5, 23, 66, 76]

# %%
names=['adhi','kevin','anadhu','alan']

# %%
names
# Out:
# ['adhi', 'kevin', 'anadhu', 'alan']

# %%
#sort names based on len

# %%
lnames=sorted(names,key=len)

# %%
lnames
# Out:
# ['adhi', 'alan', 'kevin', 'anadhu']

# %%
lnum=[i for i in range(1,10)]

# %% [markdown]
# lnum

# %% [markdown]
# lnum

# %%
lnum
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
#[1,3,5,7,9]

# %%
oddnum=[i for i in range(1,10) if i%2==1]

# %%
oddnum
# Out:
# [1, 3, 5, 7, 9]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 m
#
# NameError: name 'm' is not defined

# %%
emp={'id':1000,'name':'joe','salary':150000}

# %% [markdown]
# emp

# %% [markdown]
# emp

# %%
emp
# Out:
# {'id': 1000, 'name': 'joe', 'salary': 150000}

# %%
emp.setdefault('id',1200)
# Out:
# 1000
